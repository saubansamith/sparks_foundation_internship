# %% [markdown]
# # Exploratory Data Analysis

# %% [markdown]
# ## Author:

# %% [markdown]
# ### Mohammed Abu Bakkar Kuchikar

# %% [markdown]
# ## About Task:

# %% [markdown]
# ### To understand and analyze the data of a Super Store

# %% [markdown]
# ## Phase 1: Overview of Super Store Dataset

# %% [markdown]
# ### Importing Dependencies

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

# %% [markdown]
# ### Reading a csv file

# %%
df=pd.read_csv('SampleSuperstore.csv')
df.head()
# Out:
#         Ship Mode    Segment        Country             City       State  \
# 0    Second Class   Consumer  United States        Henderson    Kentucky
# 1    Second Class   Consumer  United States        Henderson    Kentucky
# 2    Second Class  Corporate  United States      Los Angeles  California
# 3  Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4  Standard Class   Consumer  United States  Fort Lauderdale     Florida
#
#    Postal Code Region         Category Sub-Category     Sales  Quantity  \
# 0        42420  South        Furniture    Bookcases  261.9600         2
# 1        42420  South        Furniture       Chairs  731.9400         3
# 2        90036   West  Office Supplies       Labels   14.6200         2
# 3        33311  South        Furniture       Tables  957.5775         5
# 4        33311  South  Office Supplies      Storage   22.3680         2
#
#    Discount    Profit
# 0      0.00   41.9136
# 1      0.00  219.5820
# 2      0.00    6.8714
# ...

# %%
df['Ship Mode'].unique()
# Out:
# array(['Second Class', 'Standard Class', 'First Class', 'Same Day'],
#       dtype=object)

# %% [markdown]
# ### Removing unnecessary columns from our dataset

# %%
df.drop(['Country','Postal Code','Discount'],axis='columns',inplace=True)

# %% [markdown]
# ### Checking for NULL values

# %%
df.isna().any()
# Out:
# Ship Mode       False
# Segment         False
# City            False
# State           False
# Region          False
# Category        False
# Sub-Category    False
# Sales           False
# Quantity        False
# Profit          False
# dtype: bool

# %% [markdown]
# ### Analyzing the Sales based on Categories

# %%
pd.DataFrame(df.groupby(['Category'])['Sales'].mean())
# Out:
#                       Sales
# Category
# Furniture        349.834887
# Office Supplies  119.324101
# Technology       452.709276

# %%
plt.bar(furniture['Category'],furniture['Sales'])
plt.bar(tech['Category'],tech['Sales'])
plt.bar(office['Category'],office['Sales'])
plt.grid()

# %% [markdown]
# ### Splitting the dataframe category wise

# %%
furniture=df[df['Category']=='Furniture']
tech=df[df['Category']=='Technology']
office=df[df['Category']=='Office Supplies']

# %%
plt.bar(furniture['Category'],furniture['Sales'])
plt.bar(tech['Category'],tech['Sales'])
plt.bar(office['Category'],office['Sales'])
plt.grid()

# %% [markdown]
# ### Analyzing the Profits based on Categories

# %%
pd.DataFrame(df.groupby(['Category'])['Profit'].sum())
# Out:
#                       Profit
# Category
# Furniture         18451.2728
# Office Supplies  122490.8008
# Technology       145454.9481

# %%
plt.bar(furniture['Category'],furniture['Profit'])
plt.bar(tech['Category'],tech['Profit'])
plt.bar(office['Category'],office['Profit'])
plt.grid()

# %% [markdown]
# ### Getting the frequencies of each category

# %%
pd.crosstab(df['Category'],columns=[''])
# Out:
# col_0
# Category
# Furniture        2121
# Office Supplies  6026
# Technology       1847

# %%
plt.hist(df['Category'])
# Out:
# (array([2121.,    0.,    0.,    0.,    0., 6026.,    0.,    0.,    0.,
#         1847.]),
#  array([0. , 0.2, 0.4, 0.6, 0.8, 1. , 1.2, 1.4, 1.6, 1.8, 2. ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# ### Analyzing the Sales based on Region

# %%
pd.DataFrame(df.groupby(['Region'])['Sales'].mean())
# Out:
#               Sales
# Region
# Central  215.772661
# East     238.336110
# South    241.803645
# West     226.493233

# %%
plt.bar(df['Region'],df['Sales'])
plt.grid()
plt.show()
# Out:
# <BarContainer object of 9994 artists>

# %% [markdown]
# ### Getting the frequencies of each region

# %%
pd.crosstab(df['Region'],columns=[''])
# Out:
# col_0
# Region
# Central  2323
# East     2848
# South    1620
# West     3203

# %%
plt.hist(df['Region'])
# Out:
# (array([1620.,    0.,    0., 3203.,    0.,    0., 2323.,    0.,    0.,
#         2848.]),
#  array([0. , 0.3, 0.6, 0.9, 1.2, 1.5, 1.8, 2.1, 2.4, 2.7, 3. ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# ### Analyzing the Profits based on region

# %%
pd.DataFrame(df.groupby(['Region'])['Profit'].mean())
# Out:
#             Profit
# Region
# Central  17.092709
# East     32.135808
# South    28.857673
# West     33.849032

# %%
plt.bar(df['Region'],df['Profit'])
plt.grid()
plt.show()

# %%
plt.bar(df['Region'],df['Profit'])
plt.bar(df['Category'],df['Profit'])
plt.xticks(rotation = 45, horizontalalignment = 'right')
plt.grid()
plt.show()

# %% [markdown]
# ### Splitting our dataframe region wise

# %%
south=df[df['Region']=='South']
west=df[df['Region']=='West']
east=df[df['Region']=='East']
central=df[df['Region']=='Central']

# %% [markdown]
# ### Comparing profit of categories region wise

# %%
plt.subplot(2,2,1)
plt.title('South')
plt.bar(south['Category'],south['Profit'])
plt.xticks(fontsize=5)
plt.yticks(fontsize=5)
plt.grid()

plt.subplot(2,2,2)
plt.title('West')
plt.bar(west['Category'],west['Profit'])
plt.xticks(fontsize=5)
plt.yticks(fontsize=5)
plt.grid()

plt.subplot(2,2,3)
plt.title('East')
plt.bar(east['Category'],east['Profit'])
plt.xticks(fontsize=5)
plt.yticks(fontsize=5)
plt.grid()

plt.subplot(2,2,4)
plt.title('Central')
plt.bar(central['Category'],central['Profit'])
plt.xticks(fontsize=5)
plt.yticks(fontsize=5)
plt.grid()

plt.show()

# %% [markdown]
# ### Comparing sales of categories region wise

# %%
plt.subplot(2,2,1)
plt.title('South')
plt.bar(south['Category'],south['Sales'])
plt.xticks(fontsize=5)
plt.yticks(fontsize=5)
plt.grid()

plt.subplot(2,2,2)
plt.title('West')
plt.bar(west['Category'],west['Sales'])
plt.xticks(fontsize=5)
plt.yticks(fontsize=5)
plt.grid()

plt.subplot(2,2,3)
plt.title('East')
plt.bar(east['Category'],east['Sales'])
plt.xticks(fontsize=5)
plt.yticks(fontsize=5)
plt.grid()

plt.subplot(2,2,4)
plt.title('Central')
plt.bar(central['Category'],central['Sales'])
plt.xticks(fontsize=5)
plt.yticks(fontsize=5)
plt.grid()

plt.show()

# %% [markdown]
# ### Analyzing the sales based on segments

# %%
pd.DataFrame(df.groupby('Segment')['Sales'].mean().round())
# Out:
#              Sales
# Segment
# Consumer     224.0
# Corporate    234.0
# Home Office  241.0

# %%
plt.bar(df['Segment'],df['Sales'])
plt.grid()
plt.show()

# %% [markdown]
# ### Analyzing the profits based on segments

# %%
pd.DataFrame(df.groupby('Segment')['Profit'].mean().round())
# Out:
#              Profit
# Segment
# Consumer       26.0
# Corporate      30.0
# Home Office    34.0

# %%
plt.bar(df['Segment'],df['Profit'])
plt.grid()
plt.show()

# %% [markdown]
# ### Getting the frequencies of each segment

# %%
pd.crosstab(df['Segment'],columns=[''])
# Out:
# col_0
# Segment
# Consumer     5191
# Corporate    3020
# Home Office  1783

# %%
plt.hist(df['Segment'])
plt.grid()
plt.show()

# %% [markdown]
# ## Phase 2: In-Depth Analysis

# %% [markdown]
# ### Splitting the dataframe of categories into sub-categories

# %%
furniture['Sub-Category'].unique()
# Out:
# array(['Bookcases', 'Chairs', 'Tables', 'Furnishings'], dtype=object)

# %%
bookcases_ft=furniture[furniture['Sub-Category']=='Bookcases'][['Sub-Category','Sales','Profit']]
chairs_ft=furniture[furniture['Sub-Category']=='Chairs'][['Sub-Category','Sales','Profit']]
tables_ft=furniture[furniture['Sub-Category']=='Tables'][['Sub-Category','Sales','Profit']]
furnishings_ft=furniture[furniture['Sub-Category']=='Furnishings'][['Sub-Category','Sales','Profit']]

# %%
tech['Sub-Category'].unique()
# Out:
# array(['Phones', 'Accessories', 'Machines', 'Copiers'], dtype=object)

# %%
phones_tc=tech[tech['Sub-Category']=='Phones'][['Sub-Category','Sales','Profit']]
accessories_tc=tech[tech['Sub-Category']=='Accessories'][['Sub-Category','Sales','Profit']]
machines_tc=tech[tech['Sub-Category']=='Machines'][['Sub-Category','Sales','Profit']]
copiers_tc=tech[tech['Sub-Category']=='Copiers'][['Sub-Category','Sales','Profit']]

# %%
office['Sub-Category'].unique()
# Out:
# array(['Labels', 'Storage', 'Art', 'Binders', 'Appliances', 'Paper',
#        'Envelopes', 'Fasteners', 'Supplies'], dtype=object)

# %%
labels_ofc=office[office['Sub-Category']=='Labels'][['Sub-Category','Sales','Profit']]
storage_ofc=office[office['Sub-Category']=='Storage'][['Sub-Category','Sales','Profit']]
art_ofc=office[office['Sub-Category']=='Art'][['Sub-Category','Sales','Profit']]
binders_ofc=office[office['Sub-Category']=='Binders'][['Sub-Category','Sales','Profit']]
appliances_ofc=office[office['Sub-Category']=='Appliances'][['Sub-Category','Sales','Profit']]
paper_ofc=office[office['Sub-Category']=='Paper'][['Sub-Category','Sales','Profit']]
envelopes_ofc=office[office['Sub-Category']=='Envelopes'][['Sub-Category','Sales','Profit']]
fasteners_ofc=office[office['Sub-Category']=='Fasteners'][['Sub-Category','Sales','Profit']]
supplies_ofc=office[office['Sub-Category']=='Supplies'][['Sub-Category','Sales','Profit']]

# %% [markdown]
# ### <font color='red'> Sub-Categories of Category: Furniture</font>

# %% [markdown]
# #### Analyzing the profits based on the sub-categories of furniture

# %%
furniture.groupby('Sub-Category')['Profit'].mean()
# Out:
# Sub-Category
# Bookcases     -15.230509
# Chairs         43.095894
# Furnishings    13.645918
# Tables        -55.565771
# Name: Profit, dtype: float64

# %%
plt.bar(bookcases_ft.iloc[:,0],bookcases_ft.iloc[:,2])
plt.bar(chairs_ft.iloc[:,0],chairs_ft.iloc[:,2])
plt.bar(tables_ft.iloc[:,0],tables_ft.iloc[:,2])
plt.bar(furnishings_ft.iloc[:,0],furnishings_ft.iloc[:,2])
plt.grid()
plt.show()

# %% [markdown]
# #### Analyzing the sales based on the sub-categories of furniture

# %%
furniture.groupby('Sub-Category')['Sales'].mean()
# Out:
# Sub-Category
# Bookcases      503.859633
# Chairs         532.332420
# Furnishings     95.825668
# Tables         648.794771
# Name: Sales, dtype: float64

# %%
plt.bar(bookcases_ft.iloc[:,0],bookcases_ft.iloc[:,1])
plt.bar(chairs_ft.iloc[:,0],chairs_ft.iloc[:,1])
plt.bar(tables_ft.iloc[:,0],tables_ft.iloc[:,1])
plt.bar(furnishings_ft.iloc[:,0],furnishings_ft.iloc[:,1])
plt.grid()
plt.show()

# %% [markdown]
# #### Getting the frequency of each sub-category of furniture

# %%
pd.crosstab(furniture['Sub-Category'],columns='')
# Out:
# col_0
# Sub-Category
# Bookcases     228
# Chairs        617
# Furnishings   957
# Tables        319

# %%
plt.hist(bookcases_ft.iloc[:,0])
plt.hist(chairs_ft.iloc[:,0])
plt.hist(tables_ft.iloc[:,0])
plt.hist(furnishings_ft.iloc[:,0])
# Out:
# (array([  0.,   0.,   0.,   0.,   0., 957.,   0.,   0.,   0.,   0.]),
#  array([2.5, 2.6, 2.7, 2.8, 2.9, 3. , 3.1, 3.2, 3.3, 3.4, 3.5]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# ### <font color='red'> Sub-Categories of Category: Tech</font>

# %% [markdown]
# #### Analyzing the Profits based on the sub-categories of Tech

# %%
tech.groupby('Sub-Category')['Profit'].mean()
# Out:
# Sub-Category
# Accessories     54.111788
# Copiers        817.909190
# Machines        29.432669
# Phones          50.073938
# Name: Profit, dtype: float64

# %%
plt.bar(accessories_tc.iloc[:,0],accessories_tc.iloc[:,2])
plt.bar(copiers_tc.iloc[:,0],copiers_tc.iloc[:,2])
plt.bar(machines_tc.iloc[:,0],machines_tc.iloc[:,2])
plt.bar(phones_tc.iloc[:,0],phones_tc.iloc[:,2])
plt.grid()
plt.show()

# %% [markdown]
# #### Analyzing the sales based on the sub-categories of tech

# %%
tech.groupby('Sub-Category')['Sales'].mean()
# Out:
# Sub-Category
# Accessories     215.974604
# Copiers        2198.941618
# Machines       1645.553313
# Phones          371.211534
# Name: Sales, dtype: float64

# %%
plt.bar(accessories_tc.iloc[:,0],accessories_tc.iloc[:,1])
plt.bar(copiers_tc.iloc[:,0],copiers_tc.iloc[:,1])
plt.bar(machines_tc.iloc[:,0],machines_tc.iloc[:,1])
plt.bar(phones_tc.iloc[:,0],phones_tc.iloc[:,1])
plt.grid()
plt.show()

# %% [markdown]
# #### Getting the frequency of each sub-category of tech

# %%
pd.crosstab(tech['Sub-Category'],columns='Frequency')
# Out:
# col_0         Frequency
# Sub-Category
# Accessories         775
# Copiers              68
# Machines            115
# Phones              889

# %%
plt.hist(accessories_tc.iloc[:,0])
plt.hist(copiers_tc.iloc[:,0])
plt.hist(machines_tc.iloc[:,0])
plt.hist(phones_tc.iloc[:,0])
# Out:
# (array([  0.,   0.,   0.,   0.,   0., 889.,   0.,   0.,   0.,   0.]),
#  array([2.5, 2.6, 2.7, 2.8, 2.9, 3. , 3.1, 3.2, 3.3, 3.4, 3.5]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# ### <font color='red'> Sub-Categories of Category: Office Supplies</font>

# %% [markdown]
# #### Analyzing the Profits based on the sub-categories of Office Supplies

# %%
office.groupby('Sub-Category')['Profit'].mean()
# Out:
# Sub-Category
# Appliances    38.922758
# Art            8.200737
# Binders       19.843574
# Envelopes     27.418019
# Fasteners      4.375660
# Labels        15.236962
# Paper         24.856620
# Storage       25.152277
# Supplies      -6.258418
# Name: Profit, dtype: float64

# %%
plt.bar(appliances_ofc.iloc[:,0],appliances_ofc.iloc[:,2])
plt.bar(art_ofc.iloc[:,0],art_ofc.iloc[:,2])
plt.bar(binders_ofc.iloc[:,0],binders_ofc.iloc[:,2])
plt.bar(envelopes_ofc.iloc[:,0],envelopes_ofc.iloc[:,2])
plt.bar(fasteners_ofc.iloc[:,0],fasteners_ofc.iloc[:,2])
plt.bar(labels_ofc.iloc[:,0],labels_ofc.iloc[:,2])
plt.bar(paper_ofc.iloc[:,0],paper_ofc.iloc[:,2])
plt.bar(storage_ofc.iloc[:,0],storage_ofc.iloc[:,2])
plt.bar(supplies_ofc.iloc[:,0],supplies_ofc.iloc[:,2])
plt.xticks(fontsize=6,rotation=45)
plt.grid()
plt.show()

# %% [markdown]
# #### Analyzing the sales based on the sub-categories of Office Supplies

# %%
office.groupby('Sub-Category')['Sales'].mean()
# Out:
# Sub-Category
# Appliances    230.755710
# Art            34.068834
# Binders       133.560560
# Envelopes      64.867724
# Fasteners      13.936774
# Labels         34.303055
# Paper          57.284092
# Storage       264.590553
# Supplies      245.650200
# Name: Sales, dtype: float64

# %%
plt.bar(appliances_ofc.iloc[:,0],appliances_ofc.iloc[:,1])
plt.bar(art_ofc.iloc[:,0],art_ofc.iloc[:,1])
plt.bar(binders_ofc.iloc[:,0],binders_ofc.iloc[:,1])
plt.bar(envelopes_ofc.iloc[:,0],envelopes_ofc.iloc[:,1])
plt.bar(fasteners_ofc.iloc[:,0],fasteners_ofc.iloc[:,1])
plt.bar(labels_ofc.iloc[:,0],labels_ofc.iloc[:,1])
plt.bar(paper_ofc.iloc[:,0],paper_ofc.iloc[:,1])
plt.bar(storage_ofc.iloc[:,0],storage_ofc.iloc[:,1])
plt.bar(supplies_ofc.iloc[:,0],supplies_ofc.iloc[:,1])
plt.xticks(fontsize=6,rotation=45)
plt.grid()
plt.show()

# %% [markdown]
# #### Getting the frequency of each sub-category of tech

# %%
pd.crosstab(office['Sub-Category'],columns='Frequency')
# Out:
# col_0         Frequency
# Sub-Category
# Appliances          466
# Art                 796
# Binders            1523
# Envelopes           254
# Fasteners           217
# Labels              364
# Paper              1370
# Storage             846
# Supplies            190

# %%
plt.hist(appliances_ofc.iloc[:,0],)
plt.hist(art_ofc.iloc[:,0])
plt.hist(binders_ofc.iloc[:,0])
plt.hist(envelopes_ofc.iloc[:,0])
plt.hist(fasteners_ofc.iloc[:,0])
plt.hist(labels_ofc.iloc[:,0])
plt.hist(paper_ofc.iloc[:,0])
plt.hist(storage_ofc.iloc[:,0])
plt.hist(supplies_ofc.iloc[:,0])
plt.xticks(fontsize=6,rotation=45)
plt.grid()
plt.show()

# %%
s=pd.DataFrame(df.groupby('State')[['Sales','Profit']].mean())
s
# Out:
#                             Sales      Profit
# State
# Alabama                319.846557   94.865989
# Arizona                157.508933  -15.303235
# Arkansas               194.635500   66.811452
# California             228.729451   38.171608
# Colorado               176.418231  -35.867351
# Connecticut            163.223866   42.823071
# Delaware               285.948635  103.930988
# District of Columbia   286.502000  105.958930
# Florida                233.612815   -8.875461
# Georgia                266.825217   88.315453
# Idaho                  208.689810   39.367767
# Illinois               162.939230  -25.625787
# Indiana                359.431946  123.375411
# Iowa                   152.658667   39.460397
# Kansas                 121.429583   34.851813
# Kentucky               263.250000   80.573357
# Louisiana              219.453095   52.288150
# Maine                  158.816250   56.810775
# Maryland               225.766886   66.963608
# ...

# %%
plt.bar(df['State'],df['Sales'])
plt.xticks(rotation=90,fontsize=6)
plt.show()

# %% [markdown]
# ### Analyzing the Sales based on states

# %%
s=pd.DataFrame(df.groupby('State')[['Sales','Profit']].mean())
s
# Out:
#                             Sales      Profit
# State
# Alabama                319.846557   94.865989
# Arizona                157.508933  -15.303235
# Arkansas               194.635500   66.811452
# California             228.729451   38.171608
# Colorado               176.418231  -35.867351
# Connecticut            163.223866   42.823071
# Delaware               285.948635  103.930988
# District of Columbia   286.502000  105.958930
# Florida                233.612815   -8.875461
# Georgia                266.825217   88.315453
# Idaho                  208.689810   39.367767
# Illinois               162.939230  -25.625787
# Indiana                359.431946  123.375411
# Iowa                   152.658667   39.460397
# Kansas                 121.429583   34.851813
# Kentucky               263.250000   80.573357
# Louisiana              219.453095   52.288150
# Maine                  158.816250   56.810775
# Maryland               225.766886   66.963608
# ...

# %%
plt.bar(df['State'],df['Sales'])
plt.xticks(rotation=90,fontsize=6)
plt.show()

# %% [markdown]
# ### Analyzing the Profits based on states

# %%
plt.bar(df['State'],df['Profit'])
plt.xticks(rotation=90,fontsize=6)
plt.show()

# %%
plt.hist(df['State'])
plt.xticks(rotation=90,fontsize=6)
plt.show()

# %% [markdown]
# ### Splitting the dataframe into cities of Kentucky state (which has zero loss)

# %%
kentucky=df[df['State']=='Kentucky'][['City','Sales','Profit']]
kentucky
# Out:
#             City   Sales    Profit
# 0      Henderson  261.96   41.9136
# 1      Henderson  731.94  219.5820
# 418     Richmond    5.78    2.8322
# 538    Henderson  152.94   41.2938
# 539    Henderson  283.92   70.9800
# ...          ...     ...       ...
# 9333  Georgetown   14.20    6.6740
# 9462  Louisville  701.96  168.4704
# 9785  Louisville   48.81   23.9169
# 9911    Richmond  115.36   56.5264
# 9960    Florence   18.00    3.2400
#
# [139 rows x 3 columns]

# %% [markdown]
# #### Analyzing the Sales based on cities of kentucky state

# %%
pd.DataFrame(kentucky.groupby('City')['Sales'].mean())
# Out:
#                     Sales
# City
# Bowling Green  105.905000
# Florence       455.980000
# Georgetown     223.302500
# Henderson      326.271042
# Louisville     220.466364
# Murray         132.310000
# Owensboro       35.590000
# Richmond       198.868235

# %%
plt.bar(kentucky.City,kentucky.Sales)
plt.grid()
plt.xticks(fontsize=8,rotation=45)
plt.show()

# %% [markdown]
# #### Analyzing the Profits based on cities of kentucky state

# %%
pd.DataFrame(kentucky.groupby('City')['Profit'].mean())
# Out:
#                    Profit
# City
# Bowling Green   33.558400
# Florence       183.735410
# Georgetown      50.345000
# Henderson       94.142019
# Louisville      59.875655
# Murray          47.232900
# Owensboro       13.821400
# Richmond        66.930694

# %%
plt.bar(kentucky.City,kentucky.Profit)
plt.grid()
plt.xticks(fontsize=8,rotation=45)
plt.show()

# %% [markdown]
# #### Getting Frequencies

# %%
pd.crosstab(kentucky['City'],columns='')
# Out:
# col_0
# City
# Bowling Green   2
# Florence       10
# Georgetown      8
# Henderson      48
# Louisville     33
# Murray          2
# Owensboro       2
# Richmond       34

# %%
plt.hist(kentucky.City)
plt.xticks(fontsize=8,rotation=45)
plt.show()

# %% [markdown]
# ### Details of the top sales making state (Florida)

# %%
florida=df[df['State']=='Florida'][['City','Sales','Profit']]
florida
# Out:
#                   City     Sales    Profit
# 3      Fort Lauderdale  957.5775 -383.0310
# 4      Fort Lauderdale   22.3680    2.5164
# 43           Melbourne   95.6160    9.5616
# 231              Tampa  233.8600 -102.0480
# 232              Tampa  620.6145 -248.2458
# ...                ...       ...       ...
# 9818  Saint Petersburg    4.4480    0.3336
# 9819  Saint Petersburg    9.0000    3.1500
# 9820  Saint Petersburg   42.2400   13.2000
# 9821  Saint Petersburg   18.2640  -13.3936
# 9989             Miami   25.2480    4.1028
#
# [383 rows x 3 columns]

# %% [markdown]
# #### Sales

# %%
plt.bar(florida.iloc[:,0],florida.iloc[:,1])
plt.xticks(fontsize=6,rotation=90)
plt.show()

# %% [markdown]
# #### Profit

# %%
plt.bar(florida.iloc[:,0],florida.iloc[:,2])
plt.xticks(fontsize=6,rotation=90)
plt.show()

# %% [markdown]
# ### Knowing the best ship mode for each region

# %% [markdown]
# #### Central

# %%
df['Ship Mode'].unique()
# Out:
# array(['Second Class', 'Standard Class', 'First Class', 'Same Day'],
#       dtype=object)

# %%
first_n=df[(df['Ship Mode']=='First Class') & (df['Region']=='Central')]
second_n=df[(df['Ship Mode']=='Second Class') & (df['Region']=='Central')]
standard_n=df[(df['Ship Mode']=='Standard Class') & (df['Region']=='Central')]
sameday_n=df[(df['Ship Mode']=='Same Day') & (df['Region']=='Central')]

# %% [markdown]
# ###### Sales

# %%
plt.bar(first_n['Ship Mode'],first_n['Sales'],width=0.4)
plt.bar(second_n['Ship Mode'],second_n['Sales'],width=0.4)
plt.bar(standard_n['Ship Mode'],standard_n['Sales'],width=0.4)
plt.bar(sameday_n['Ship Mode'],sameday_n['Sales'],width=0.4)
plt.show()

# %% [markdown]
# ##### Profit

# %%
plt.bar(first_n['Ship Mode'],first_n['Profit'],width=0.4)
plt.bar(second_n['Ship Mode'],second_n['Profit'],width=0.4)
plt.bar(standard_n['Ship Mode'],standard_n['Profit'],width=0.4)
plt.bar(sameday_n['Ship Mode'],sameday_n['Profit'],width=0.4)
plt.show()

# %% [markdown]
# #### West

# %%
first_w=df[(df['Ship Mode']=='First Class') & (df['Region']=='West')]
second_w=df[(df['Ship Mode']=='Second Class') & (df['Region']=='West')]
standard_w=df[(df['Ship Mode']=='Standard Class') & (df['Region']=='West')]
sameday_w=df[(df['Ship Mode']=='Same Day') & (df['Region']=='West')]

# %% [markdown]
# ##### Sales

# %%
plt.bar(first_w['Ship Mode'],first_w['Sales'],width=0.4)
plt.bar(second_w['Ship Mode'],second_w['Sales'],width=0.4)
plt.bar(standard_w['Ship Mode'],standard_w['Sales'],width=0.4)
plt.bar(sameday_w['Ship Mode'],sameday_w['Sales'],width=0.4)
plt.show()

# %% [markdown]
# ##### Profit

# %%
plt.bar(first_w['Ship Mode'],first_w['Profit'],width=0.4)
plt.bar(second_w['Ship Mode'],second_w['Profit'],width=0.4)
plt.bar(standard_w['Ship Mode'],standard_w['Profit'],width=0.4)
plt.bar(sameday_w['Ship Mode'],sameday_w['Profit'],width=0.4)
plt.show()

# %% [markdown]
# #### East

# %%
df['Ship Mode'].unique()
# Out:
# array(['Second Class', 'Standard Class', 'First Class', 'Same Day'],
#       dtype=object)

# %%
first_e=df[(df['Ship Mode']=='First Class') & (df['Region']=='East')]
second_e=df[(df['Ship Mode']=='Second Class') & (df['Region']=='East')]
standard_e=df[(df['Ship Mode']=='Standard Class') & (df['Region']=='East')]
sameday_e=df[(df['Ship Mode']=='Same Day') & (df['Region']=='East')]

# %% [markdown]
# ##### Sales

# %%
plt.bar(first_e['Ship Mode'],first_e['Sales'],width=0.4)
plt.bar(second_e['Ship Mode'],second_e['Sales'],width=0.4)
plt.bar(standard_e['Ship Mode'],standard_e['Sales'],width=0.4)
plt.bar(sameday_e['Ship Mode'],sameday_e['Sales'],width=0.4)
plt.show()

# %% [markdown]
# ##### Profit

# %%
plt.bar(first_e['Ship Mode'],first_e['Profit'],width=0.4)
plt.bar(second_e['Ship Mode'],second_e['Profit'],width=0.4)
plt.bar(standard_e['Ship Mode'],standard_e['Profit'],width=0.4)
plt.bar(sameday_e['Ship Mode'],sameday_e['Profit'],width=0.4)
plt.show()

# %% [markdown]
# #### South

# %%
df['Ship Mode'].unique()
# Out:
# array(['Second Class', 'Standard Class', 'First Class', 'Same Day'],
#       dtype=object)

# %%
first_s=df[(df['Ship Mode']=='First Class') & (df['Region']=='South')]
second_s=df[(df['Ship Mode']=='Second Class') & (df['Region']=='South')]
standard_s=df[(df['Ship Mode']=='Standard Class') & (df['Region']=='South')]
sameday_s=df[(df['Ship Mode']=='Same Day') & (df['Region']=='South')]

# %% [markdown]
# ##### Sales

# %%
plt.bar(first_s['Ship Mode'],first_s['Sales'],width=0.4)
plt.bar(second_s['Ship Mode'],second_s['Sales'],width=0.4)
plt.bar(standard_s['Ship Mode'],standard_s['Sales'],width=0.4)
plt.bar(sameday_s['Ship Mode'],sameday_s['Sales'],width=0.4)
plt.show()

# %% [markdown]
# ##### Profit

# %%
plt.bar(first_s['Ship Mode'],first_s['Profit'],width=0.4)
plt.bar(second_s['Ship Mode'],second_s['Profit'],width=0.4)
plt.bar(standard_s['Ship Mode'],standard_s['Profit'],width=0.4)
plt.bar(sameday_s['Ship Mode'],sameday_s['Profit'],width=0.4)
plt.show()

# %% [markdown]
# ## Phase 3: Synopsis

# %% [markdown]
# - Fix the problems occuring in categories:
#   - Technology
#   - Office Supplies
# - Solve the issues of **consumer**, if we are still having losses through them, then stop supplying to them
# - Stop delivering products with **first class** to the region:
#     - Central
#     - West
# - Stop delivering products on the **same day** to the southern region
# - Delivering products with **Standard class** is recommended
# - Decrease the supply of:
#     - Tables (Furniture)
#     - Supplies (Office Supplies)
# - Stop supplying products to the state **Ohio**
# - Fix the problems occuring in **Jacksonville** of the state **Florida**
# - Solve the problems occuring in:
#     - Binders (Office Supplies)
#     - Phone (Technology)
#     - Machine (Technology)
#     - Furnishings (Furniture)
# - Increase the supply of **chairs**
